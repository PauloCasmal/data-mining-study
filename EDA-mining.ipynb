# %% [markdown]
# # Mining Process Dataset – EDA
#
# This script serves as a base to further analyses, transformations, and inferations. The code is divided into three main parts, which are:
# 1. Imports & Configurations;
# 2. Dataset treatment;
# 3. Ploting Charts.
#
# **Responsible:** Paulo Casmal
#
# **Email:** <paulo.casmal@gmail.com>
#
# **Date:** 12-13-2025
#
# ---

# %% [markdown]
# ## 01 - Imports & Configurations

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configuration of matplotlib parameters for consistent styling
mpl.rcParams['figure.figsize'] = (10, 6)  # Default figure size
mpl.rc('lines', lw=2)  # Sets the line width
mpl.rcParams['grid.linewidth'] = 0.5  # Grid line width
mpl.rcParams['grid.linestyle'] = 'dashed'  # Grid line style
mpl.rc(('xtick', 'ytick'), labelsize=15)  # Axis tick label size
mpl.rc('font', family='Times New Roman', size=15)  # Font family and font size
mpl.rcParams['axes.linewidth'] = 0.5 # - Largura das bordas dos gráficos

# %%
# Load the dataset
path = r'C:\Users\paulo\Downloads\archive (2)\MiningProcess_Flotation_Plant_Database.csv'

df = pd.read_csv(path, decimal=',')

df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
# ...

# %% [markdown]
# ## Columns overview
# - C01:       Datetime;
# - C02 - C03: Iron quality neasurement before flotation;
# - C04 - C08: Most important variables to predict quality of ore at the end of the process;
# - C09 - C22: Level of air flow that also impact final quality;
# - C23:       Target

# %%
for ind, col in enumerate(df.columns):
    print(ind, col)
# Out:
# 0 date
# 1 % Iron Feed
# 2 % Silica Feed
# 3 Starch Flow
# 4 Amina Flow
# 5 Ore Pulp Flow
# 6 Ore Pulp pH
# 7 Ore Pulp Density
# 8 Flotation Column 01 Air Flow
# 9 Flotation Column 02 Air Flow
# 10 Flotation Column 03 Air Flow
# 11 Flotation Column 04 Air Flow
# 12 Flotation Column 05 Air Flow
# 13 Flotation Column 06 Air Flow
# 14 Flotation Column 07 Air Flow
# 15 Flotation Column 01 Level
# 16 Flotation Column 02 Level
# 17 Flotation Column 03 Level
# 18 Flotation Column 04 Level
# 19 Flotation Column 05 Level
# 20 Flotation Column 06 Level
# 21 Flotation Column 07 Level
# 22 % Iron Concentrate
# 23 % Silica Concentrate

# %% [markdown]
# # teste

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          737453 non-null  object
#  1   % Iron Feed                   737453 non-null  float64
#  2   % Silica Feed                 737453 non-null  float64
#  3   Starch Flow                   737453 non-null  float64
#  4   Amina Flow                    737453 non-null  float64
#  5   Ore Pulp Flow                 737453 non-null  float64
#  6   Ore Pulp pH                   737453 non-null  float64
#  7   Ore Pulp Density              737453 non-null  float64
#  8   Flotation Column 01 Air Flow  737453 non-null  float64
#  9   Flotation Column 02 Air Flow  737453 non-null  float64
#  10  Flotation Column 03 Air Flow  737453 non-null  float64
#  11  Flotation Column 04 Air Flow  737453 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
df.isna().sum()
# Out:
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
# Convert 'date' column to datetime and set as index
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

# %% [markdown]
# ## 03 - Correlation Analysis

# %%
correlations = df.corr()[['% Silica Concentrate']].T

plt.figure(figsize=(20, 3))
sns.heatmap(
    correlations,
    annot=True,        # show correlation values
    fmt=".2f",
    cmap="coolwarm",
    square=True,
    linewidths=0.5
)

plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 04 - Statistical Metrics Analysis

# %%
df.describe().T
# Out:
#                                  count         mean          std         min  \
# % Iron Feed                   737453.0    56.294739     5.157744   42.740000
# % Silica Feed                 737453.0    14.651716     6.807439    1.310000
# Starch Flow                   737453.0  2869.140569  1215.203734    0.002026
# Amina Flow                    737453.0   488.144697    91.230534  241.669000
# Ore Pulp Flow                 737453.0   397.578372     9.699785  376.249000
# Ore Pulp pH                   737453.0     9.767639     0.387007    8.753340
# Ore Pulp Density              737453.0     1.680380     0.069249    1.519820
# Flotation Column 01 Air Flow  737453.0   280.151856    29.621288  175.510000
# Flotation Column 02 Air Flow  737453.0   277.159965    30.149357  175.156000
# Flotation Column 03 Air Flow  737453.0   281.082397    28.558268  176.469000
# Flotation Column 04 Air Flow  737453.0   299.447794     2.572538  292.195000
# ...

# %%
plt.figure(figsize=(20, 6))

plt.plot(df.index, df['% Silica Concentrate'])

plt.show()

# %%
week = df[(df.index > '2017-04-10 01:00:00') & (df.index < '2017-04-17 01:00:00')]

# %%
plt.figure(figsize=(20, 6))

plt.plot(week.index, week['% Silica Concentrate'], '-o')

plt.grid()
plt.show()

# %%
n_cols = 4
n_rows = int(np.ceil(len(df.columns) / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4 * n_rows))
axes = axes.flatten()

for ax, col in zip(axes, df.columns):
    ax.boxplot(df[col])
    ax.set_title(col, fontsize=10)
    ax.grid(True, linestyle='--', alpha=0.5)

# Remove eixos vazios
for ax in axes[len(df.columns):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 6))
df.boxplot(rot=90)
plt.title('Boxplot de todas as variáveis')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 05 - Stationary Analysis
