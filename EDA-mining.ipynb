# %% [markdown]
# # Mining Process Dataset – EDA
#
# This script serves as a base to further analyses, transformations, and inferences. The code is divided into six main parts, which are:
# 1. Imports & Configurations;
# 2. Sample Rate Analysis;
# 3. Correlation Analysis;
# 4. Statistical Metrics Analysis
# 5. Boxplots;
# 6. Augmented Dickey Fuller (ADF) Test.
#
# **Responsible:** Paulo Casmal
#
# **Email:** <paulo.casmal@gmail.com>
#
# **Date:** 12-13-2025 | **Submission Date:** 01-04-2026
#
# ---

# %% [markdown]
# ## 01 - Imports & Configurations

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configuration of matplotlib parameters for consistent styling
mpl.rcParams['figure.figsize'] = (10, 6)  # Default figure size
mpl.rc('lines', lw=2)  # Sets the line width
mpl.rcParams['grid.linewidth'] = 0.5  # Grid line width
mpl.rcParams['grid.linestyle'] = 'dashed'  # Grid line style
mpl.rc(('xtick', 'ytick'), labelsize=15)  # Axis tick label size
mpl.rc('font', family='Century Gothic', size=15)  # Font family and font size
mpl.rcParams['axes.linewidth'] = 0.5 # - Largura das bordas dos gráficos

# %%
# Load the dataset
path = r'C:\Users\paulo\Downloads\archive (2)\MiningProcess_Flotation_Plant_Database.csv'

df = pd.read_csv(path, decimal=',')

df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
# ...

# %% [markdown]
# Columns overview:
# - C01:       Datetime;
# - C02 - C03: Iron quality measurement before flotation;
# - C04 - C08: Most important variables to predict quality of
# - ore at the end of the process;
# - C09 - C22: Level of air flow that also impact final quality;
# - C23:       Target.
#
# Information obtained from dataset page on kaggle - [Kaggle Link](https://www.kaggle.com/datasets/edumagalhaes/quality-prediction-in-a-mining-process).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          737453 non-null  object
#  1   % Iron Feed                   737453 non-null  float64
#  2   % Silica Feed                 737453 non-null  float64
#  3   Starch Flow                   737453 non-null  float64
#  4   Amina Flow                    737453 non-null  float64
#  5   Ore Pulp Flow                 737453 non-null  float64
#  6   Ore Pulp pH                   737453 non-null  float64
#  7   Ore Pulp Density              737453 non-null  float64
#  8   Flotation Column 01 Air Flow  737453 non-null  float64
#  9   Flotation Column 02 Air Flow  737453 non-null  float64
#  10  Flotation Column 03 Air Flow  737453 non-null  float64
#  11  Flotation Column 04 Air Flow  737453 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 1171

# %%
print(f'Duplicates:')
print(f'{df.duplicated().sum()} - {(df.duplicated().sum() / df.count().max() * 100).round(2)}%')
# Out:
# Duplicates:
# 1171 - 0.16%

# %% [markdown]
# ### Verifying Null/NA values

# %%
df.isnull().sum()
# Out:
# date                            0
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
df.isna().sum()
# Out:
# date                            0
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
# Convert 'date' column to datetime and set as index
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

# %% [markdown]
# ## 02 - Sample Rate Analysis

# %%
day = df[(df.index > '2017-04-15 00:00:00') & (df.index < '2017-04-16 00:00:00')]

fig, ax = plt.subplots(2, 1, figsize=(10, 6), sharex=True)

ax[0].plot(day.index, day['% Silica Concentrate'], label='% Silica Concentrate - 1h', marker='o', linestyle='solid', markersize=4, alpha=0.5, c='#0B1741')
ax[1].plot(day.index, day['Starch Flow'], label='Starch Flow - 20s', marker='o', linestyle='solid', markersize=4, alpha=0.5, c='#B2275F')

ax[0].set_ylabel('% Silica Concentrate', fontsize=15)
ax[1].set_ylabel('Starch Flow [kg/h]', fontsize=15)
ax[1].set_xlabel('Date', fontsize=15)

ax[0].legend(loc=2)
ax[1].legend(loc=2)

ax[0].set_title('Variables with Different Sampling Rates', fontsize=16)

plt.tight_layout()

fig.savefig(r'G:\Meu Drive\03 - Facens\03 - Data Science\02-TCC-POS\05-Figures\sample-rate-analysis.svg', dpi=140, format='svg')

plt.show()

# %% [markdown]
# ## 03 - Correlation Analysis

# %%
# Correlation matrix heatmap - focusing on '% Silica Concentrate' (taget variable)
correlations = df.corr()[['% Silica Concentrate']].T

plt.figure(figsize=(24, 3))

sns.heatmap(
    correlations,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    square=True,
    linewidths=0.5
)

plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
df.columns = (
    df.columns
      .str.replace('Flotation Column', 'F.C.', case=False, regex=True)
)

target = '% Silica Concentrate'

corr = (
    df.corr(numeric_only=True)[target]
      .drop(target)
      .sort_values()
)

# %%
fig, ax = plt.subplots(figsize=(7, 5))

y_pos = np.arange(len(corr))

# Limites do eixo X
xmin, xmax = corr.min() * 1.1, corr.max() * 1.1
ax.set_xlim(xmin, xmax)

# Margem (sobra) — ajuste fino aqui
pad = 0.05 * (xmax - xmin)

# "Grid" horizontal com sobra
ax.hlines(
    y=y_pos,
    xmin=xmin + pad * 0.8,
    xmax=np.where(
        corr.values < 0,
        corr.values - pad * 0.8,   # negativo → até a barra
        -0.03                       # positivo → valor fixo
    ),
    color='black',
    linewidth=0.8,
    alpha=0.7,
    zorder=0
)


# Barras
ax.barh(
    y_pos,
    corr.values,
    color='#B2275F',
    height=0.6,
    zorder=2
)

ax.set_yticks(y_pos)
ax.set_yticklabels(corr.index, fontsize=11)

ax.set_xlabel('Correlation with % Silica Concentrate')
ax.set_title('Feature Correlation with Target')

# Linha vertical no zero
ax.axvline(0, color='gray', linestyle='--', linewidth=1, zorder=1)

# Limpa bordas (opcional, estilo paper)
# for spine in ['top', 'right', 'left']:
#     ax.spines[spine].set_visible(False)

plt.tight_layout()

fig.savefig(r'G:\Meu Drive\03 - Facens\03 - Data Science\02-TCC-POS\05-Figures\variables-correlation.svg', dpi=140, format='svg')

plt.show()

# %% [markdown]
# ## 04 - Statistical Metrics Analysis

# %%
df.describe().T
# Out:
#                          count         mean          std         min  \
# % Iron Feed           737453.0    56.294739     5.157744   42.740000
# % Silica Feed         737453.0    14.651716     6.807439    1.310000
# Starch Flow           737453.0  2869.140569  1215.203734    0.002026
# Amina Flow            737453.0   488.144697    91.230534  241.669000
# Ore Pulp Flow         737453.0   397.578372     9.699785  376.249000
# Ore Pulp pH           737453.0     9.767639     0.387007    8.753340
# Ore Pulp Density      737453.0     1.680380     0.069249    1.519820
# F.C. 01 Air Flow      737453.0   280.151856    29.621288  175.510000
# F.C. 02 Air Flow      737453.0   277.159965    30.149357  175.156000
# F.C. 03 Air Flow      737453.0   281.082397    28.558268  176.469000
# F.C. 04 Air Flow      737453.0   299.447794     2.572538  292.195000
# F.C. 05 Air Flow      737453.0   299.917814     3.636579  286.295000
# F.C. 06 Air Flow      737453.0   292.071485    30.217804  189.928000
# ...

# %%
fig_hist, ax = plt.subplots(figsize=(7, 5))

ax.hist(df['% Silica Concentrate'], bins=75, color='#B2275F')

ax.set_xlabel('Silica Concentrate [%]')
ax.set_ylabel('Samples')

ax.set_yticks([0, 10_000, 20_000, 30_000, 40_000])
ax.set_xticks(range(7))

ax.set_title('Target Distribution')

plt.tight_layout()

fig_hist.savefig(r'G:\Meu Drive\03 - Facens\03 - Data Science\02-TCC-POS\05-Figures\target-distribution.svg', dpi=140, format='svg', transparent=True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 6))

ax.plot(df.index, df['% Silica Concentrate'], c='#0B1741')

ax.set_title("Time Series of '% Silica Concentrate' (Target)")
ax.set_xlabel("Date")
ax.set_ylabel("Silica Concentrate [%]")

fig.savefig(r'G:\Meu Drive\03 - Facens\03 - Data Science\02-TCC-POS\05-Figures\target-variable.svg', dpi=140, format='svg')

plt.show()

# %%
week = df[(df.index > '2017-04-10 01:00:00') & (df.index < '2017-04-17 01:00:00')]

# %%
plt.figure(figsize=(20, 6))

plt.plot(week.index, week['% Silica Concentrate'], '-o')

plt.title("Weekly View of % Silica Concentrate")
plt.xlabel("Date")
plt.ylabel("% Silica Concentrate")
plt.grid()

plt.show()

# %% [markdown]
# ## 05 - Boxplots

# %% [markdown]
# ### Columns overview
# - C01:       Datetime;
# - C02 - C03: Iron quality neasurement before flotation;
# - C04 - C08: Most important variables to predict quality of ore at the end of the process;
# - C09 - C22: Level of air flow that also impact final quality;
# - C23:       Target
#
# Information obtained from dataset page on kaggle - [Kaggle Link](https://www.kaggle.com/datasets/edumagalhaes/quality-prediction-in-a-mining-process).

# %%
df.columns
# Out:
# Index(['% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density', 'F.C. 01 Air Flow',
#        'F.C. 02 Air Flow', 'F.C. 03 Air Flow', 'F.C. 04 Air Flow',
#        'F.C. 05 Air Flow', 'F.C. 06 Air Flow', 'F.C. 07 Air Flow',
#        'F.C. 01 Level', 'F.C. 02 Level', 'F.C. 03 Level', 'F.C. 04 Level',
#        'F.C. 05 Level', 'F.C. 06 Level', 'F.C. 07 Level', '% Iron Concentrate',
#        '% Silica Concentrate'],
#       dtype='object')

# %%
df_01 = df.iloc[:, 0:2]
df_02 = df.iloc[:, 2:7]
df_03 = df.iloc[:, 7:14]
df_04 = df.iloc[:, 14:21]
df_05 = df.iloc[:, 21]
df_06 = df.iloc[:, 22]

dfs = [df_01, df_02, df_03, df_04, df_05, df_06]

# %%
def break_label(label, max_len=15):
    if len(label) <= max_len:
        return label
    mid = len(label) // 2
    return label[:mid] + '\n' + label[mid:]

# %%
for i, subset in enumerate(dfs):
    try:
        if isinstance(subset, pd.Series):
            subset = subset.to_frame()

        plt.figure(figsize=(13, 4))

        vp = plt.violinplot(
            subset.values,
            showmeans=False,
            showmedians=False,
            showextrema=False
        )

        for body in vp['bodies']:
            body.set_alpha(0.4)

        subset.boxplot(rot=0)

        labels = [break_label(col) for col in subset.columns]
        plt.xticks(range(1, len(labels) + 1), labels)

        plt.title(f'Subset {i+1}')
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Erro no subset {i}: {e}")

# %% [markdown]
# ## 06 - Augmented Dickey Fuller (ADF) Test
#
# Applying ADF to check if the target variable is stationary or not. The null hypothesis of the ADF is that the time series is non-stationary. So, if the p-value of the test is less than the significance level (0.05) then we can reject the null hypothesis and infer the time series is indeed stationary.
#
# Script from: [DecisionForest](https://www.youtube.com/watch?v=gqryqIlvEoM) (Youtube channel)

# %%
from statsmodels.tsa.stattools import adfuller

series = df['% Silica Concentrate'].dropna().sample(5000, random_state=42)

result = adfuller(series)

print('ADF Statistic:', result[0])
print('p-value:', result[1])

for k, v in result[4].items():
    print('Critical Value (%s): %.3f' % (k, v))
# Out:
# ADF Statistic: -69.42683641748702
# p-value: 0.0
# Critical Value (1%): -3.432
# Critical Value (5%): -2.862
# Critical Value (10%): -2.567

# %% [markdown]
# Therefore, the target variable is likely stationary, confirming the visual analysis.

# %% [markdown]
# ---
